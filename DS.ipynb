# %%
import numpy as np
import pandas as pd
import datetime

# %%
def dateconverter(day, month, year):
    return datetime(year, month, day)
# Out:
# datetime.datetime(12, 5, 4, 0, 0)

# %%
df = pd.read_csv("Hotel Reservations.csv")
df
# Out:
#       Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0       INN00001             2               0                     1
# 1       INN00002             2               0                     2
# 2       INN00003             1               0                     2
# 3       INN00004             2               0                     0
# 4       INN00005             2               0                     1
# ...          ...           ...             ...                   ...
# 36270   INN36271             3               0                     2
# 36271   INN36272             2               0                     1
# 36272   INN36273             2               0                     2
# 36273   INN36274             2               0                     0
# 36274   INN36275             2               0                     1
#
#        no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# ...

# %%
df[df["arrival_date"] > 30]
# Out:
#       Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 76      INN00077             3               0                     1
# 103     INN00104             2               0                     0
# 181     INN00182             2               0                     1
# 247     INN00248             2               0                     0
# 456     INN00457             2               1                     1
# ...          ...           ...             ...                   ...
# 35681   INN35682             1               0                     0
# 35877   INN35878             2               0                     0
# 35923   INN35924             2               1                     2
# 35964   INN35965             2               0                     0
# 36012   INN36013             2               1                     2
#
#        no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# ...

# %%
df['date'] = df.apply(lambda row: datetime.datetime(row['arrival_year'], row['arrival_month'], row['arrival_date']), axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13868/3375853939.py in <module>
# ----> 1 df['date'] = df.apply(lambda row: datetime.datetime(row['arrival_year'], row['arrival_month'], row['arrival_date']), axis=1)
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    8738             kwargs=kwargs,
#    8739         )
# -> 8740         return op.apply()
#    8741
#    8742     def applymap(
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\apply.py in apply(self)
#     686             return self.apply_raw()
#     687
# --> 688         return self.apply_standard()
#     689
# ...
